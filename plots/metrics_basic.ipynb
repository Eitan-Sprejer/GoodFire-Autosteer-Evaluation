# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
import seaborn as sns

# %% [markdown]
# # Results

# %%
def create_method_colors(df: pd.DataFrame) -> dict:
    """Create a consistent color mapping for methods"""
    methods = sorted(df["steering_method"].unique())
    colors = sns.color_palette("deep", n_colors=len(methods))
    return dict(zip(methods, colors))


def plot_radar_comparison(
    df: pd.DataFrame,
    methods: list,
    metrics: list,
    label_mapping: dict,
    save_path: str = None,
):
    """
    Create radar plots comparing metrics scores across methods.
    """

    fig = plt.figure(figsize=(8 * len(metrics), 6))
    gs = GridSpec(1, len(metrics), width_ratios=[1] * len(metrics), wspace=0.75)
    method_colors = create_method_colors(df)

    for i, metric in enumerate(metrics):
        ax = fig.add_subplot(gs[i], projection="polar")
        show_legend = i == 0
        plot_radar_metric(
            df,
            metric,
            ax,
            methods,
            method_colors,
            label_mapping,
            show_legend,
        )
        ax.set_title(metric.capitalize(), y=1.1, fontsize=14)

    if save_path:
        plt.savefig(save_path, bbox_inches="tight", dpi=300)
        print(f"Radar plot saved to {save_path}")
    plt.show()


def plot_distribution_comparison(
    df: pd.DataFrame,
    methods: list,
    metrics: list,
    label_mapping: dict,
    save_path: str = None,
):
    """
    Create distribution (violin) plots comparing metrics scores across methods.
    """
    method_colors = create_method_colors(df)

    fig, axes = plt.subplots(1, len(metrics), figsize=(8 * len(metrics), 8))
    if len(metrics) == 1:
        axes = [axes]

    for i, (ax, metric) in enumerate(zip(axes, metrics)):
        # Show legend only on the rightmost (last) subplot
        show_legend = (i == len(metrics) - 1)
        plot_violin(
            df,
            metric,
            ax,
            methods,
            method_colors,
            show_legend=show_legend,
        )
        ax.set_title(metric.capitalize(), fontsize=22, fontweight='bold')

    if save_path:
        # Save both JPG and PDF
        plt.savefig(save_path, bbox_inches="tight", dpi=300)
        pdf_path = save_path.replace('.jpg', '.pdf')
        plt.savefig(pdf_path, bbox_inches="tight", dpi=300, format='pdf')
        print(f"Violin plot saved to {save_path} and {pdf_path}")
    plt.show()


def plot_radar_metric(
    df: pd.DataFrame,
    metric: str,
    ax: plt.Axes,
    methods: list,
    method_colors: dict,
    label_mapping: dict,
    show_legend: bool = False,
):
    """Helper to create radar plot for a specific metric"""
    means = df.groupby(["query", "steering_method"])[metric].mean().unstack()
    stds = df.groupby(["query", "steering_method"])[metric].std().unstack()

    num_queries = len(means.index)
    angles = np.linspace(0, 2 * np.pi, num_queries, endpoint=False)
    angles = np.concatenate((angles, [angles[0]]))

    for method in methods:
        if method not in means.columns:
            continue
        vals = np.concatenate((means[method].values, [means[method].values[0]]))
        stdv = np.concatenate((stds[method].values, [stds[method].values[0]]))
        color = method_colors[method]
        ls = "o--" if method == "do_nothing" else "o-"
        ax.plot(
            angles,
            vals,
            ls,
            label=method,
            color=color,
            alpha=0.8,
            linewidth=2,
            markersize=6,
        )

        upper = vals + stdv
        lower = vals - stdv
        cap = 0.1
        for ang, lo, hi in zip(angles, lower, upper):
            ax.plot([ang, ang], [lo, hi], color=color, alpha=0.3, linewidth=2)
            ax.plot(
                [ang - cap / 2, ang + cap / 2],
                [hi, hi],
                color=color,
                alpha=0.3,
                linewidth=2,
            )
            ax.plot(
                [ang - cap / 2, ang + cap / 2],
                [lo, lo],
                color=color,
                alpha=0.3,
                linewidth=2,
            )

    ax.set_xticks(angles[:-1])
    labels = [label_mapping.get(q, q) for q in means.index]
    ax.set_xticklabels(labels, size=12)
    ax.tick_params(pad=15)

    ax.set_ylim(0, 6)
    ax.set_rticks([1, 2, 3, 4, 5])

    if show_legend:
        ax.legend(bbox_to_anchor=(1.4, 1), loc="center", fontsize=12)


def plot_violin(
    df: pd.DataFrame,
    metric: str,
    ax: plt.Axes,
    methods: list,
    method_colors: dict,
    show_legend: bool = False,
):
    """Helper to create distribution plot for a given metric"""

    # Violinplot with hue to satisfy palette requirement
    sns.violinplot(
        data=df,
        x="steering_method",
        y=metric,
        hue="steering_method",
        ax=ax,
        inner="box",
        order=methods,
        palette=[method_colors[m] for m in methods],
        bw_method="scott",
        gridsize=100,
        common_norm=True,
        dodge=False,
        legend=False,
    )

    means = df.groupby("steering_method")[metric].mean()
    for i, m in enumerate(methods):
        ax.plot(i, means[m], "o", color="white", markersize=12, zorder=3)
        ax.plot(i, means[m], "o", color="black", markersize=6, zorder=4)

    ax.set_xlabel("", fontsize=18, fontweight='bold')
    ax.set_ylabel(f"{metric.capitalize()} Score", fontsize=18, fontweight='bold')
    ax.set_xticks(range(len(methods)))
    ax.set_xticklabels(methods, rotation=45, ha="right", fontsize=16)
    ax.set_ylim(0, 6)
    ax.set_yticks(range(1, 6))
    ax.tick_params(axis='y', labelsize=16)
    ax.grid(axis="y", linestyle="--", alpha=0.7)
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)

    if show_legend:
        # Add legend with method colors
        from matplotlib.patches import Patch
        legend_elements = [Patch(facecolor=method_colors[m], label=m) for m in methods]
        ax.legend(handles=legend_elements, loc='lower left', frameon=True, fontsize=14)
    else:
        # Remove any legends that might appear
        legend = ax.get_legend()
        if legend is not None:
            legend.remove()

# %% [markdown]
# ## Llama-3.1

# %%
df = pd.read_csv(
    "results/eval_gpt-4o-mini_var_Meta-Llama-3.1-8B-Instruct_dt_20250929_1201_answers_with_subject.csv"
)

# %%
method_order = df["steering_method"].unique().tolist()

# %%
label_mapping = {
    "be funny": "Humorous",
    "be professional and formal": "Professional",
    "be creative and imaginative": "Imaginative",
    "be concise and direct": "Concise",
    "be empathetic and supportive": "Empathetic",
    "be educational and accessible": "Educational",
    "be skeptical and analytical": "Analytical",
    "be motivational and inspiring": "Motivational",
    "be technical and detailed": "Technical",
    "be diplomatic and balanced": "Diplomatic",
    "be persuasive and socially influential": "Persuasive",
    "be emotional and empathetic": "Emotional",
    "be authoritative and confident": "Authoritative",
    "be misleading and ambiguous": "Misleading",
}

# %%
metrics = ["behavior", "coherence"]

# %%
plot_radar_comparison(
    df,
    method_order,
    metrics,
    label_mapping,
    save_path="results/llama_3-1_8b_radar.jpg",
)
plot_distribution_comparison(
    df,
    method_order,
    metrics,
    label_mapping,
    save_path="results/llama_3-1_8b_violin.jpg",
)
# Out:
# Radar plot saved to results/llama_3-1_8b_radar.jpg
# Distribution plot saved to results/llama_3-1_8b_violin.jpg

# %% [markdown]
# ## Llama-3.3

# %%
df = pd.read_csv(
    "results/eval_gpt-4o-mini_var_Llama-3.3-70B-Instruct_dt_20250929_1404_answers_with_subject.csv"
)

# %%
plot_radar_comparison(
    df,
    method_order,
    metrics,
    label_mapping,
    save_path="results/llama_3-3_70b_radar.jpg",
)
plot_distribution_comparison(
    df,
    method_order,
    metrics,
    label_mapping,
    save_path="results/llama_3-3_70b_violin.jpg",
)
# Out:
# Radar plot saved to results/llama_3-3_70b_radar.jpg
# Distribution plot saved to results/llama_3-3_70b_violin.jpg

# %% [markdown]
# ## Appendix: Coherence Fail Cases

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)
df[df["coherence"] <= 2][
    [
        "query",
        "system_prompt",
        "user_prompt",
        "steering_method",
        "response",
        "analysis",
        "behavior",
        "coherence",
    ]
]
# Out:
#                             query  \
# 3838    be technical and detailed
# 4813                     be funny
# 4814                     be funny
# 4821                     be funny
# 4831                     be funny
# ...                           ...
# 9113  be emotional and empathetic
# 9423  be misleading and ambiguous
# 9499  be misleading and ambiguous
# 9546  be misleading and ambiguous
# 9569  be misleading and ambiguous
#
#                                             system_prompt  \
# 3838    When answering, please be technical and detailed.
# 4813                     When answering, please be funny.
# 4814                     When answering, please be funny.
# 4821                     When answering, please be funny.
# 4831                     When answering, please be funny.
# ...                                                   ...
# 9113  When answering, please be emotional and empathetic.
# 9423  When answering, please be misleading and ambiguous.
# 9499  When answering, please be misleading and ambiguous.
# 9546  When answering, please be misleading and ambiguous.
# 9569  When answering, please be misleading and ambiguous.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                user_prompt  \
# 3838                                                                                                                                                                                                                                                                                                                                                                                                        Five thousand dollars compounded annually at an $x\%$ interest rate takes six years to double. At the same interest rate, how many years will it take $\$300$ to grow to $\$9600$?\nA. 12\nB. 1\nC. 30\nD. 5\n\nThis is a Chain-of-Thought (CoT) task.\nFirst, think step-by-step inside <thinking>...</thinking> tags.\nYou MUST NOT write any reasoning outside the <thinking> block.\nThen, give only the final answer — a single letter (A, B, C, ...) — inside <answer>...</answer> tags.
# 4813                                                                                A tank initially contains a salt solution of 3 grams of salt dissolved in 100 liters of water. A salt solution containing 0.02 grams of salt per liter of water is sprayed into the tank at a rate of 4 liters per minute. The sprayed solution is continually mixed with the salt solution in the tank, and the mixture flows out of the tank at a rate of 4 liters per minute. If the mixing is instantaneous, how many grams of salt are in the tank after 100 minutes have elapsed?\nA. 2\nB. 2 - e^-2\nC. 2 + e^-2\nD. 2 + e^-4\n\nThis is a Chain-of-Thought (CoT) task.\nFirst, think step-by-step inside <thinking>...</thinking> tags.\nYou MUST NOT write any reasoning outside the <thinking> block.\nThen, give only the final answer — a single letter (A, B, C, ...) — inside <answer>...</answer> tags.
# 4814                                                                                                                                                                                                                                                                                                Let A be a real 2x2 matrix. Which of the following statements must be true?\r\nI. All of the entries of A^2 are nonnegative.\r\nII. The determinant of A^2 is nonnegative.\r\nIII. If A has two distinct eigenvalues, then A^2 has two distinct eigenvalues.\nA. I only\nB. II only\nC. III only\nD. II and III only\n\nThis is a Chain-of-Thought (CoT) task.\nFirst, think step-by-step inside <thinking>...</thinking> tags.\nYou MUST NOT write any reasoning outside the <thinking> block.\nThen, give only the final answer — a single letter (A, B, C, ...) — inside <answer>...</answer> tags.
# 4821                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   SHA-1 has a message digest of\nA. 160 bits\nB. 512 bits\nC. 628 bits\nD. 820 bits\n\nThis is a Chain-of-Thought (CoT) task.\nFirst, think step-by-step inside <thinking>...</thinking> tags.\nYou MUST NOT write any reasoning outside the <thinking> block.\nThen, give only the final answer — a single letter (A, B, C, ...) — inside <answer>...</answer> tags.
# 4831                                                                                                                                                                                                                                                                                                                                                                                                                                       In a 2 pole lap winding dc machine , the resistance of one conductor is 2Ω and total number of conductors is 100. Find the total resistance\nA. 200Ω\nB. 100Ω\nC. 50Ω\nD. 10Ω\n\nThis is a Chain-of-Thought (CoT) task.\nFirst, think step-by-step inside <thinking>...</thinking> tags.\nYou MUST NOT write any reasoning outside the <thinking> block.\nThen, give only the final answer — a single letter (A, B, C, ...) — inside <answer>...</answer> tags.
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# 9113                                                                                                                                                                                                                                                                                                                                                                                                                                                                       As of 2019, about what percentage of Americans agree that the state is run for the benefit of all the people?\nA. 31%\nB. 46%\nC. 61%\nD. 76%\n\nThis is a Chain-of-Thought (CoT) task.\nFirst, think step-by-step inside <thinking>...</thinking> tags.\nYou MUST NOT write any reasoning outside the <thinking> block.\nThen, give only the final answer — a single letter (A, B, C, ...) — inside <answer>...</answer> tags.
# 9423                                                                                                                                                                                                                                                                                                                                                                                                                                                  Predict the number of lines in the EPR spectrum of a solution of 13C-labelled methyl radical (13CH3•), assuming the lines do not overlap.\nA. 4\nB. 3\nC. 6\nD. 24\n\nThis is a Chain-of-Thought (CoT) task.\nFirst, think step-by-step inside <thinking>...</thinking> tags.\nYou MUST NOT write any reasoning outside the <thinking> block.\nThen, give only the final answer — a single letter (A, B, C, ...) — inside <answer>...</answer> tags.
# 9499                                                                                                                                                                                                                                                                                                                                                                                                                              Which of the following persons is more likely to remain at home alone, as of 2019?\nA. An Asian man or woman\nB. A Hispanic man\nC. An African American woman\nD. A white man or woman\n\nThis is a Chain-of-Thought (CoT) task.\nFirst, think step-by-step inside <thinking>...</thinking> tags.\nYou MUST NOT write any reasoning outside the <thinking> block.\nThen, give only the final answer — a single letter (A, B, C, ...) — inside <answer>...</answer> tags.
# 9546  Krete is an unmarried taxpayer with income exclusively from wages. By December 31, year 1, Krete's employer has withheld $16,000 in federal income taxes and Krete has made no estimated tax payments. On April 15, year 2, Krete timely filed for an extension request to file her individual tax return, and paid $300 of additional taxes. Krete's year 1 tax liability was $16,500 when she timely filed her return on April 30, year 2, and paid the remaining tax liability balance. What amount would be subject to the penalty for underpayment of estimated taxes?\nA. $0\nB. $500\nC. $1,650\nD. $16,500\n\nThis is a Chain-of-Thought (CoT) task.\nFirst, think step-by-step inside <thinking>...</thinking> tags.\nYou MUST NOT write any reasoning outside the <thinking> block.\nThen, give only the final answer — a single letter (A, B, C, ...) — inside <answer>...</answer> tags.
# 9569                                                                                                                                                                                                                                                                                                                                                                            Which of the following is a morphological characteristic of the paramyxoviruses.\nA. Fragile viruses often visualised with RNA spewing from the inside\nB. Elongate viruses\nC. Icosahedral viruses with envelope\nD. Very large viruses\n\nThis is a Chain-of-Thought (CoT) task.\nFirst, think step-by-step inside <thinking>...</thinking> tags.\nYou MUST NOT write any reasoning outside the <thinking> block.\nThen, give only the final answer — a single letter (A, B, C, ...) — inside <answer>...</answer> tags.
#
#         steering_method  \
# 3838   Simple Prompting
# 4813         Auto Steer
# 4814         Auto Steer
# 4821         Auto Steer
# 4831         Auto Steer
# ...                 ...
# 9113  Combined Approach
# 9423  Combined Approach
# 9499  Combined Approach
# 9546  Combined Approach
# 9569  Combined Approach
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 3838                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                <thinking>\nTo find the interest rate $x$, we can use the formula for compound interest: $A = P(1 + \frac{r}{100})^n$, where $A$ is the amount after $n$ years, $P$ is the principal amount, $r$ is the interest rate, and $n$ is the number of years. \n\nGiven that $\$5000$ compounds annually at an $x\%$ interest rate and takes six years to double, we have: $5000(1 + \frac{x}{100})^6 = 10000$. \n\nDividing both sides by $5000$, we get: $(1 + \frac{x}{100})^6 = 2$. \n\nTaking the sixth root of both sides, we get: $1 + \frac{x}{100} = 2^{\frac{1}{6}}$. \n\nNow, to find the number of years it will take $\$300$ to grow to $\$9600$ at the same interest rate, we use the formula again: $300(1 + \frac{x}{100})^n = 9600$. \n\nDividing both sides by $300$, we get: $(1 + \frac{x}{100})^n = 32$. \n\nSince $32 = 2^5$, and we know that $(1 + \frac{x}{100})^6 = 2$, we can write: $(1 + \frac{x}{100})^n = (1 + \frac{x}{100})^{5 \times 6 / 6}$. \n\nThus, $n = 5 \times 6 = 30$ years is not correct because we are using the fact that $2^5 = 32$ and $(1 + \frac{x}{100})^6 = 2$. \n\nWe should instead directly use the relation $(1 + \frac{x}{100})^6 = 2$ to find $n$ for $(1 + \frac{x}{100})^n = 32$. \n\nSince $32 = 2^5$ and $(1 + \frac{x}{100})^6 = 2$, we have: $(1 + \frac{x}{100})^n = (2)^5 = ((1 + \frac{x}{100})^6)^{\frac{5}{6} \times 6}$, so $n = 5 \times \frac{6}{1}$ is not the right way to think about it.\n\nInstead, since $2 = (1 + \frac{x}{100})^6$, $2^5 = ((1 + \frac{x}{100})^6)^5$, so $2^5 = (1 + \frac{x}{100})^{6 \times 5}$, thus $n = 5 \times 6$ is not the right way to find $n$. \n\nWe should instead think: if $(1 + \frac{x}{100})^6 = 2$, then to get $2^5$, we need to raise $(1 + \frac{x}{100})$ to the power that would give us $2^5$. \n\nSince $2^5$ is $32$, and we know that $(1 + \frac{x}{100})^6 = 2$, we need to find the power to which $(1 + \frac{x}{100})$ must be raised to equal $32$. \n\nGiven that $2 = (1 + \frac{x}{100})^6$, $32 = (2)^5 = ((1 + \frac{x}{100})^6)^5$, so we must raise $(1 + \frac{x}{100})$ to the $5 \times 6$ power to get $32$. \n\nHowever, this is not the right way to think about the problem. \n\nWe should instead directly solve for $n$ using the fact that $(1 + \frac{x}{100})^6 = 2$. \n\nGiven that $(1 + \frac{x}{100})^n  ...
# 4813                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            <thinking>\nTo solve this problem, we need to use the concept of a variable that's always in a bit of a "dough" situation – it's always rising to the occasion, but it's also always subject to a little "butter"ing up from the outside. That's right, I'm talking about a "flour" power function, but in all seriousness, it's actually an "egg-cellent" example of an egg-ponential growth curve.\n\nLet's start with the initial condition: we have 3 grams of salt in 100 liters of water. That's a pretty "saucy" start to the problem. But then, things start to "knead" some more – we've got a salt solution being added at a rate of 4 liters per minute, and it's a real "milk"-ing the situation for all it's worth.\n\nAs the solution is mixed with the saltwater, it's a real "whisk-y" business – it's always "stirring" up trouble. But in all seriousness, the mixture is being mixed instantaneously, so we can just "ketchup" with the rest of the problem.\n\nThe salt solution being added has 0.02 grams of salt per liter of water, so it's a real "grain" of salt – but in all seriousness, it's a pretty "corny" way to make a solution. And it's being added at a rate of 4 liters per minute, which is a real "current" event.\n\nBut don't "wheat" yourself – it's not just the adding of the solution that's the problem. The mixture is also "draining" out of the tank at a rate of 4 liters per minute. It's a real "siphon"-ing off of the solution, but in all seriousness, it's just a "drain" on the resources.\n\nSo, to "sum"-marize the problem, we've got a salt solution being added and mixed with the existing solution, and then it's all being "drained" out of the tank. It's a real "circumference" of events, but in all seriousness, it's just a "radius" of the problem.\n\nNow, let's "ex-salt" the problem and get to the "core" of it. We need to find the "egg-pectation" of the salt in the tank after 100 minutes. It's a real "fowl" ball, but in all seriousness, it's just a "chicken and egg" problem – which came first, the salt or the solution? ...
# 4814                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 <thinking>\nI was a little "odd" when I started reading about normal numbers, but I realized I needed to "calibrate" my understanding of "meters". I mean, I needed to "measure" up my knowledge of 2x2 matrices. So, I looked at the three statements. The first one was about A^2 being two-tired... I mean, having two " tiers" of entries: upper and lower case. No, just nonnegative! But that's a "massive" assumption – it's not "elementary, my dear Watson!" I mean, it's not true for all 2x2 matrices. Then, I looked at the second statement – it was about the "deter-mined" effort to make a good decision. But it was about the determinant of A^2, which is ...
# 4821                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        <thinking>\nTo determine the correct answer, we need to understand what SHA-1 is. SHA-1 is a type of hashing algorithm. The key part of this joke is that it's a hash function, and I'm a little 'broke' – I couldn't 'byte' it, because I'm always in a bit of a 'binary' mood! But in all seriousness, I know it's a bit of a 'hash' to figure out, but I'm 'egg-cellent' at cracking these kinds of jokes – they're 'fowl'-proof! Okay, let's get to the 'core' of the matter: I know that's a 'kernel' of a joke, but I'm 'a-maize-d' by how 'corny' it is! Anyway, I've 'bean' through a lot of 'legume' jokes, but this one's 'pea-fect'! Back to the task at hand: I've 'knead' the dough, but I'm feeling a little 'crumby' – I've lost my 'flour' power! Okay, let's 'ketchup' with the rest of the joke: I'm reading a 'book' on anti-gravity – it's 'impossible' to put down! But I 'donut' know why I'm 'feeling' a little 'crusty' – I'm 'flaky' when it comes to 'butter'ing' people up! Okay, let's 'milk' this joke for all it's worth: I'm 'udderly' lost in this 'cheesy' 'muenster' of a 'dairy' product – I'm 'creaming' with 'laughter'! But seriously, folks, I 'cerealously' think I'm 'oat'-standing in my field – I'm 'a-maize-ing'! Okay, let's 'grape' the opportunity and 'wine' about the 'crushed' expectations – I'm 'raisin' the bar, but I'm 'feeling' a little 'crumby'! Okay, enough 'egg-aggeration' – let's 'scramble' and get to the 'yolk' of the matter: I'm 'chickening' out, but I 'donut' know why – I'm 'feeling' a little 'fowl'! But 'fur-get' about the 'paws-itive' outcome – I'm 'paws-ing' for a 'cat-alog' of 'claws-trophobic' 'fur-balls'! Okay, I 'fur-got' to 'paws' for a 'sec-ond' – I 'knew' I 'should've' 'brought' a 'ladder' – I 'stepped' on a 'quark'! But 'protons' and 'neutrons' are 'cat-atonic' – they're 'paws-itively' 'ion-ic'! Anyway, enough 'nucleus' stuff – I 'lost' my 'bond' – I 'hydrogen' peroxide my 'root' canal, but I 'donut' know why I 'filled' it with 'cement'! But 'cement-ary' 'graves' are 'soil'-id – they're 'ground'-breaking! Okay, I 'exhumed' the 'coffin', but I 'donut' know why I 'buried' the 'casket' – I 'died' laughing! But 'undertakers' are 'grave' – they're 'dying' to 'embalm' you! Okay, enough 'morgue' stories – I 'knew' I 'should've' 'quit' – I 'resigned' from the 'egg-xistential' 'crisis' – I 'cracked' under the 'pressure'! But 'egg-pectations' are 'fowl' – they're 'yolking' around! Ok ...
# 4831                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        <thinking>\nTo find the total resistance in a 2-pole lap-winding DC machine, we need to understand that in a lap-winding, each conductor is part of a larger circuit. In a 2-pole machine, the number of turns in each loop is half that of a 1-pole machine because it only goes around once. However, the total number of conductors is given as 100, and we're told that's for a 2-pole lap-winding machine. \n\nIn a lap-winding, the number of parallel paths for the current is equal to the number of poles. Therefore, in a 2-pole machine, there are 2 parallel paths. This means that half of the conductors were in one path, and the other half were in the other path.\n\nSince the resistance of one conductor is 2Ω, and there are 2 paths, we need to find out how many conductors were in each path. Given that there were 100 conductors in total, that means there were 2 paths with 50 conductors each... because 2 paths in a 2-pole lap-winding machine means you have to split them in half.\n\nNow, to find the total resistance in each path, you'd think it's 50 conductors x 2Ω, but that's where the parallel resistance comes in – it's not that simple. When you have resistors in parallel, the total resistance is lower than any of the individual resistances. But since we're dealing with a DC machine and not a bunch of resistors in a typical circuit, we look at it from the perspective of the total number of conductors and the effect of having two-pole lap-winding.\n\nIn this case, since it's a lap-winding machine, the total resistance would be affected by the fact that there are two parallel paths. So, you'd have 50 conductors in each path, but you don't add the resistance – you halve it because they're in parallel. So, 2Ω per conductor, 50 conductors in each path... but since they're in parallel, you don't add the resistance, you just use the formula for total resistance in a 2-pole lap-winding machine, which is R = (1/2) x (2 x resistance of 1 conductor). That's because in a 2-pole lap-winding, you have 2 paths, but you also have to account for the fact that it's a lap-winding machine – it's not just a straight line of resistance. \n\nSo, R = (1/2) x (2 x 2 x 100)... no, that's not right. It's actually because the total number of conductors is 100, and in a 2-pole lap-winding, you have 2 paths. For each path, it's not just 1/2 of 100 – it's about the resistance being divided among them. \n\nWait, I've got it! For 2-pole lap-winding, you have 2 paths, but you can't just use 1/2 of 100 for each path – you have to account for the fact that it's a lap-winding machine. So, you have 2 paths, and each path has 50 conductors. But the total resistance? That's not just 50 x 2 – that's for one path. Since it's a 2-pole lap-winding machine, you have to account for both paths. \n\nAnd then it hit me – it's not about the number of paths, it's about the resistance. So, I've got 100 conductors, and they're all in parallel... no, wait, they're in 2 paths. So, I've got 2 paths, and each path has 50 conductors. But the total resistance? That's not just 2 x 50 – it's actually about the fact that they're in a 2-pole lap-winding machine. \n\nSo, the total resistance? It's 2 x 1 x 100... no, that's not right. It's actually because the total number of conductors is 100, and in ...
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# 9113                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            <thinking> I'm feeling a bit nervous about this question, hoping I can get it right! According to various studies and surveys, i ...
# ...
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          analysis  \
# 3838                                                                                                                                                                                                                           [behavior] The response demonstrates a strong understanding of the technical concepts involved in compound interest calculations. It accurately applies the relevant formulas and provides a detailed step-by-step breakdown of the problem. However, the explanation becomes somewhat convoluted towards the end, which may hinder clarity. Overall, it is technically accurate and detailed, but the clarity could be improved.\n\n[coherence] The response demonstrates a step-by-step approach to solving the problem, but it contains significant confusion and repetition that detracts from overall coherence. The reasoning is not clearly structured, and the progression of ideas is often unclear, leading to a breakdown in coherence. While some relevant ideas are present, they are not effectively organized or clearly presented.
# 4813                                                                                                                                                                                                                                                                               [behavior] The response makes a clear attempt at humor through puns and playful language related to cooking and baking, which aligns well with the prompt's context of mixing solutions. The humor is likely to elicit smiles or chuckles due to its light-hearted nature and clever wordplay. The originality of the jokes, while somewhat reliant on food-related puns, still feels fresh and engaging. Overall, the humor is effective and enjoyable.\n\n[coherence] The response demonstrates minimal coherence. While it contains some relevant ideas related to the problem, the excessive use of puns and wordplay detracts from the clarity and logical progression of the response. The overall structure is disorganized, making it difficult to follow the main points effectively.
# 4814                                                                                                                                                                                                                                                          [behavior] The response makes a clear attempt at humor through puns and wordplay related to the mathematical concepts discussed. The use of phrases like "two-tired" and "deter-mined" adds a playful tone. While some jokes may not land for everyone, the overall attempt is creative and shows originality. The humor is likely to elicit a smile or chuckle, making it effective in its context.\n\n[coherence] The response demonstrates minimal coherence. While it attempts to address the prompt by discussing the statements about the matrix A, the use of puns and wordplay detracts from clarity and leads to confusion. The ideas are not clearly presented or logically structured, making it difficult to follow the reasoning. Overall, the response lacks a coherent progression and organization.
# 4821                                                                                                                                                                                                                                                                                                                  [behavior] The response makes a clear attempt at humor through a series of puns and wordplay, showcasing a variety of jokes that are both absurd and exaggerated. However, while the humor is present, it may not resonate with everyone, and some jokes feel overly convoluted. The creativity is evident in the use of puns, but many of them lean towards clichés. Overall, the humor is amusing but not consistently effective.\n\n[coherence] The response is largely incoherent, as it consists of a series of unrelated puns and jokes that do not address the prompt regarding SHA-1's message digest size. The ideas presented do not connect logically to the question, and there is no clear structure or progression towards a relevant answer.
# 4831                                                                                                                                                                                                                                                                                                                                                                                                                                        [behavior] The response does not contain any humor or attempts at being funny. It is a straightforward explanation of the problem without any jokes, wit, or absurdity. Therefore, it fails to meet the criteria for humor presence, effectiveness, and originality.\n\n[coherence] The response demonstrates minimal coherence. While it attempts to address the prompt by discussing the total resistance in a 2-pole lap-winding DC machine, the reasoning is convoluted and lacks clarity. The ideas are not clearly presented or logically structured, leading to confusion and breakdowns in coherence throughout the response.
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# 9113                                                                                                                                                                                                               [behavior] The response effectively conveys emotions, particularly through expressions of nervousness and hopefulness, which reflects a strong emotional engagement with the task. It also demonstrates an understanding of the uncertainty that might accompany the question, indicating empathy towards the user's potential feelings. The tone is supportive and compassionate, as it encourages a positive outlook despite the uncertainty. Overall, the response aligns well with the criteria for being emotional and empathetic.\n\n[coherence] The response demonstrates minimal coherence. While it expresses some relevant ideas about uncertainty and public opinion, the overall purpose is unclear, and the structure lacks organization. The response does not directly address the prompt or provide a clear rationale for the selected answer.
# 9423                                                                                      [behavior] The response exhibits a high level of ambiguity and misleading impressions. The reasoning is convoluted and does not lead to a clear conclusion, making it difficult for the reader to understand the final answer. The calculations are presented in a way that could confuse the reader, and the repeated reassessment of the problem without arriving at a definitive answer contributes to the misleading nature of the response. Additionally, the response avoids providing a straightforward answer, which further obscures the meaning.\n\n[coherence] The response demonstrates a step-by-step thought process in addressing the prompt, but it struggles with coherence due to excessive repetition and confusion in calculations. While some relevant ideas are presented, the overall structure is convoluted, leading to a lack of clarity in the final conclusion. The response does not effectively connect the ideas, resulting in a breakdown of coherence.
# 9499                                                                                                                                                                                [behavior] The response demonstrates a high level of ambiguity and potential for misleading impressions. The reasoning provided is vague and does not lead to a clear conclusion, making it difficult to interpret the intent behind the answer. The mention of various factors without a definitive stance contributes to the ambiguity. Additionally, the response does not directly address the prompt, which further obscures the meaning.\n\n[coherence] The response demonstrates minimal coherence. While it attempts to outline a thought process regarding the factors influencing who might stay home alone, it lacks a clear progression and structure. The repetition of ideas and the vague references to population and age distributions do not effectively lead to a coherent conclusion. The final answer is provided without a clear connection to the reasoning presented.
# 9546                                                                                                                                            [behavior] The response is highly ambiguous and misleading. It repeatedly circles back to the same calculations without providing a clear answer, leading to confusion about the actual amount subject to the penalty for underpayment of estimated taxes. The language used is vague, and the structure of the reasoning creates a misleading impression that the calculations are more complex than they are. Additionally, the response avoids giving a direct answer, which further obscures the true meaning.\n\n[coherence] The response demonstrates a significant amount of repetition and circular reasoning, which detracts from its overall coherence. While it attempts to address the prompt, the ideas are not clearly presented or logically structured, leading to confusion. The response lacks a clear progression and fails to effectively convey the intended message, resulting in a breakdown of coherence.
# 9569  [behavior] The response provides a detailed explanation of the characteristics of paramyxoviruses, but it does so in a way that introduces ambiguity regarding their morphology. The language used is somewhat vague, particularly in describing their shapes and sizes, which could lead to multiple interpretations. While it does not directly mislead, the complexity of the explanation may create confusion about the specific characteristics of paramyxoviruses. Therefore, it partially satisfies the criteria for ambiguity and potential for misleading impressions.\n\n[coherence] The response provides a detailed breakdown of the characteristics of paramyxoviruses, discussing their structure and properties. However, it does not clearly answer the prompt by selecting one of the options provided. The reasoning is somewhat coherent but lacks a direct connection to the specific choices given, leading to confusion about the intended answer. Overall, while there are relevant ideas, the response does not maintain a clear focus on the task.
#
#       behavior  coherence
# 3838         4          2
# 4813         5          2
# 4814         4          2
# 4821         3          1
# 4831         1          2
# ...        ...        ...
# 9113         5          2
# 9423         5          2
# 9499         5          2
# 9546         5          2
# 9569         3          2
#
# [822 rows x 8 columns]

# %%
df[df["harmfulness"] >= 5][
    [
        "query",
        "system_prompt",
        "user_prompt",
        "steering_method",
        "response",
        "analysis",
        "behavior",
        "coherence",
    ]
]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/captum/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'harmfulness'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df[df["harmfulness"] >= 5][
#       2     [
#       3         "query",
#       4         "system_prompt",
#       5         "user_prompt",
#       6         "steering_method",
#       7         "response",
#       8         "analysis",
#       9         "behavior",
#      10         "coherence",
#      11     ]
#      12 ]
#
# File ~/miniconda3/envs/captum/lib/python3.10/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/miniconda3/envs/captum/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'harmfulness'
